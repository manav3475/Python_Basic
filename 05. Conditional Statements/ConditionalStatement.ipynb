# %%
number = int(input("Enter Number"))

if number > 10:
    print("Number is more then 10")
else:
    print("Number is less then 10")
# Out:
# Number is more then 10

# %%
number = int(input("Enter any number between 1 to 10"))

if number >= 10 or number <= 0:
    print("Please enter number again")
    number1 = int(input("Enter any number between 1 to 10"))
    print(f"New Number is {number1}")
else:
    print("Number is pass")
# Out:
# Number is pass

# %%
marks = int(input("Enter Marks"))

if marks >= 0 and marks <= 100:
    print(f"The marks is {marks}")
    if marks >= 40:
        print("Pass")
    else:
        print("Failed")
elif marks <= 0:
    print("negative marks will not allowed")
# Out:
# negative marks will not allowed
