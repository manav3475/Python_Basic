# %%
a = 5

# %%
a
# Out:
# 5

# %%
testing = 12345

# %%
testing
# Out:
# 12345

# %%
a = 676
b = 887.5467
c = 5 + 45j

# %%
type(a)
# Out:
# int

# %%
type(b)
# Out:
# float

# %%
type(c)
# Out:
# complex

# %%
g = True
type(g)
# Out:
# bool
