# %% [markdown]
# ## List

# %%
data_list = [12,11,11,44,35,55,33,55,"Jay","Exam"]

# %%
type(data_list)
# Out:
# list

# %%
len(data_list)
# Out:
# 10

# %%
data_list[-1]
# Out:
# 'Exam'

# %%
data_list[1:3]
# Out:
# [11, 11]

# %%
data_list[:5]
# Out:
# [12, 11, 11, 44, 35]

# %%
data_list[::2]
# Out:
# [12, 11, 35, 33, 'Jay']

# %%
data_list[2] = "Ram"
data_list
# Out:
# [12, 11, 'Ram', 44, 35, 55, 33, 55, 'Jay', 'Exam']

# %%
data_list[8:10] = [44,10]
data_list
# Out:
# [12, 11, 'Ram', 44, 35, 55, 33, 55, 44, 10]

# %%
data_list.append("Nikhil")
data_list
# Out:
# [12, 11, 'Ram', 44, 35, 55, 33, 55, 44, 10, 'Nikhil']

# %%
data_list.remove(55)
data_list
# Out:
# [12, 11, 'Ram', 44, 35, 33, 44, 10, 'Nikhil']

# %%
data_list.pop(1)
data_list
# Out:
# [12, 'Ram', 44, 35, 33, 44, 10, 'Nikhil']

# %%
data_list.pop()
# Out:
# 'Nikhil'

# %%
del data_list

# %%
data_list.clear()
data_list
# Out:
# []

# %%
list_sort = [11,12,22,3]
list_sort.sort()
list_sort
# Out:
# [3, 11, 12, 22]

# %%
list_sort.sort(reverse=True)
list_sort
# Out:
# [22, 12, 11, 3]

# %%
list_sort.reverse()
list_sort
# Out:
# [3, 11, 12, 22]

# %% [markdown]
# ### Copy

# %%
l = list_sort
l
# Out:
# [3, 11, 12, 22]

# %%
l1 = l.copy()
l1
# Out:
# [3, 11, 12, 22]

# %%
l.reverse()
l
# Out:
# [22, 12, 11, 3]

# %%
list_sort # Deep copy
# Out:
# [22, 12, 11, 3]

# %%
l1 # shallow copy
# Out:
# [3, 11, 12, 22]

# %%
l5 = ["Jay","Sai","Ram"]
l6 = [1,55,6766]

join_list = l5 + l6
join_list
# Out:
# ['Jay', 'Sai', 'Ram', 1, 55, 6766]

# %%
l5 = ["Jay","Sai","Ram"]
l6 = [1,55,6766]

l5.extend(l6)
l5
# Out:
# ['Jay', 'Sai', 'Ram', 1, 55, 6766]

# %% [markdown]
# ## Tuple

# %%
t1 = ("Apple",22,11,867,22,"Man")
type(t1)
# Out:
# tuple

# %%
t1[2] = 44
t1
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[217], line 1
# ----> 1 t1[2] = 44
#       2 t1
#
# TypeError: 'tuple' object does not support item assignment

# %%
t2 = ("FFFF",)
type(t2)
# Out:
# tuple

# %%
t1[-1:]
# Out:
# ('Man',)

# %%
t1[2:4]
# Out:
# (11, 867)

# %% [markdown]
# ## Sets

# %%
s1 = {"Apple","Raj",11,22,44,44}
type(s1)
s1
# Out:
# {11, 22, 44, 'Apple', 'Raj'}

# %%
s1.add(642434)
s1
# Out:
# {11, 22, 44, 642434, 'Apple', 'Raj'}

# %%
s2 = {"Manav","Rohan","Riddhi",333,434}
s2
# Out:
# {333, 434, 'Manav', 'Riddhi', 'Rohan'}

# %%
s2.remove(333)
s2
# Out:
# {434, 'Manav', 'Riddhi', 'Rohan'}

# %%
s2.discard("Rohan")
s2
# Out:
# {434, 'Manav', 'Riddhi'}

# %%
s2.pop()
# Out:
# 'Manav'

# %% [markdown]
# ## Dictionaries

# %%
d1 = {
  "brand": "Ford",
  "model": "Mustang",
  "year": 1964
}

# %%
print(d1["brand"])
# Out:
# Ford

# %%
print(len(d1))
# Out:
# 3

# %%
d1.items()
# Out:
# dict_items([('brand', 'Ford'), ('model', 'Mustang'), ('year', 1964)])

# %%
d1.values()
# Out:
# dict_values(['Ford', 'Mustang', 1964])

# %%
d1.get("model")
# Out:
# 'Mustang'

# %%
d1.keys()
# Out:
# dict_keys(['brand', 'model', 'year'])

# %%
d1["year"] = 2012
d1
# Out:
# {'brand': 'Ford', 'model': 'Mustang', 'year': 2012}

# %%
d1["color"] = "red"
print(d1)
# Out:
# {'brand': 'Ford', 'model': 'Mustang', 'year': 2012, 'color': 'red'}

# %%
d1.pop("color")
print(d1)
# Out:
# {'brand': 'Ford', 'model': 'Mustang', 'year': 2012}
