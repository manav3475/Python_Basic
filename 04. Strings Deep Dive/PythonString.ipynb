# %% [markdown]
# ## Python Strings

# %% [markdown]
# ### Strings in python are surrounded by either single quotation marks, or double quotation marks.

# %%
t = """You have 10,000 documents.

       Your RAG fetches only top 5.

       The correct answer is in document number 9,999."""

d = "Hello Team"

s = 'Hello'

print(s)
print(type(s))
print(d)
print(type(d))
# Out:
# Hello
# <class 'str'>
# Hello Team
# <class 'str'>

# %% [markdown]
# ### Slicling Operation

# %% [markdown]
# #### -5 -4 -3  -2  -1
#
# #### H  e   l   l   o
#
# #### 0  1   2   3   4

# %%
s[0:]
# Out:
# 'Hello'

# %%
s[-1:4]
# Out:
# ''

# %%
s[0:5]
# Out:
# 'Hello'

# %%
s[-1:-3]
# Out:
# ''

# %%
s[-3:-1]
# Out:
# 'll'

# %%
s[::2]
# Out:
# 'Hlo'

# %%
s[::-1]
# Out:
# 'olleH'

# %%
s.upper()
# Out:
# 'HELLO'

# %%
s.lower()
# Out:
# 'hello'

# %%
m = "     Hello       "

m.strip()
# Out:
# 'Hello'

# %%
s.replace("l","f")
# Out:
# 'Heffo'

# %%
s.split('o')
# Out:
# ['Hell', '']

# %%
Extra = 11_29 #1129 #11_11_29_11
                    #11112911

# %%
type(Extra)
# Out:
# int
